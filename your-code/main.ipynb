# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import requests as req
import pandas as pd
import json

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %%
# your code here
main_repo = req.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks')
forks = main_repo.json()
forks
# Out:
# [{u'archive_url': u'https://api.github.com/repos/aiborra11/mad-oct-2018/{archive_format}{/ref}',
#   u'archived': False,
#   u'assignees_url': u'https://api.github.com/repos/aiborra11/mad-oct-2018/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/aiborra11/mad-oct-2018/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/aiborra11/mad-oct-2018/branches{/branch}',
#   u'clone_url': u'https://github.com/aiborra11/mad-oct-2018.git',
#   u'collaborators_url': u'https://api.github.com/repos/aiborra11/mad-oct-2018/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/aiborra11/mad-oct-2018/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/aiborra11/mad-oct-2018/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/aiborra11/mad-oct-2018/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/aiborra11/mad-oct-2018/contents/{+path}',
# ...

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here
langs = []
for i in range(len(forks)):
    o = req.get(forks[i]['languages_url']).json()
    langs.append(o.keys())

langs
# Out:
# [[u'Python', u'Jupyter Notebook', u'HTML'],
#  [u'Python', u'Jupyter Notebook', u'HTML'],
#  [u'Python', u'Jupyter Notebook', u'HTML'],
#  [u'Python', u'Jupyter Notebook', u'HTML'],
#  [u'Python', u'Shell', u'Jupyter Notebook', u'HTML'],
#  [u'Python', u'Jupyter Notebook', u'HTML'],
#  [u'Python'],
#  [u'Python', u'Jupyter Notebook', u'HTML'],
#  [u'Python', u'Jupyter Notebook', u'HTML'],
#  [u'Python', u'Jupyter Notebook'],
#  [u'Python', u'Jupyter Notebook', u'HTML'],
#  [u'Python', u'Jupyter Notebook', u'HTML'],
#  [u'Python', u'Jupyter Notebook', u'HTML']]

# %%
languages = []
for x in langs:
    for y in x:
        if y not in languages:
            languages.append(y)
            
languages
# Out:
# [u'Python', u'Jupyter Notebook', u'HTML', u'Shell']

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the past week.
# #### 1. Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here
main_repo = req.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits')
commits = main_repo.json()
commits
# Out:
# [{u'author': {u'avatar_url': u'https://avatars1.githubusercontent.com/u/47005065?v=4',
#    u'events_url': u'https://api.github.com/users/ta-data-bcn/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/ta-data-bcn/followers',
#    u'following_url': u'https://api.github.com/users/ta-data-bcn/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/ta-data-bcn/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/ta-data-bcn',
#    u'id': 47005065,
#    u'login': u'ta-data-bcn',
#    u'node_id': u'MDQ6VXNlcjQ3MDA1MDY1',
#    u'organizations_url': u'https://api.github.com/users/ta-data-bcn/orgs',
#    u'received_events_url': u'https://api.github.com/users/ta-data-bcn/received_events',
#    u'repos_url': u'https://api.github.com/users/ta-data-bcn/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/ta-data-bcn/starred{/owner}{/repo}',
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here
len(commits)
# Out:
# 30

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here
response = req.get('https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger')
hey = response.json()

# %%
paths = []
for i in range(len(hey['items'])):
    paths.append(hey['items'][i]['path'])
    
paths

files = hey['items']

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here
files = sorted(files, key=lambda x: x['name'])

# %%
files
# Out:
# [{u'git_url': u'https://api.github.com/repositories/162375181/git/blobs/2add7632f1323136324efbf38ec66db1838b6173',
#   u'html_url': u'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/98750/.0001.scavengerhunt',
#   u'name': u'.0001.scavengerhunt',
#   u'path': u'98750/.0001.scavengerhunt',
#   u'repository': {u'archive_url': u'https://api.github.com/repos/ironhack-datalabs/scavenger/{archive_format}{/ref}',
#    u'assignees_url': u'https://api.github.com/repos/ironhack-datalabs/scavenger/assignees{/user}',
#    u'blobs_url': u'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs{/sha}',
#    u'branches_url': u'https://api.github.com/repos/ironhack-datalabs/scavenger/branches{/branch}',
#    u'collaborators_url': u'https://api.github.com/repos/ironhack-datalabs/scavenger/collaborators{/collaborator}',
#    u'comments_url': u'https://api.github.com/repos/ironhack-datalabs/scavenger/comments{/number}',
# ...

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.

# %%
# your code here
content = []
for x in range(len(files)):
    path = files[x]['path']
    read = req.get('https://api.github.com/repos/ironhack-datalabs/scavenger/contents/'+path)
    txt = read.json()
    content.append(txt)
    
content
# Out:
# [{u'documentation_url': u'https://developer.github.com/v3/#rate-limiting',
#   u'message': u"API rate limit exceeded for 83.39.225.24. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)"},
#  {u'documentation_url': u'https://developer.github.com/v3/#rate-limiting',
#   u'message': u"API rate limit exceeded for 83.39.225.24. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)"},
#  {u'documentation_url': u'https://developer.github.com/v3/#rate-limiting',
#   u'message': u"API rate limit exceeded for 83.39.225.24. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)"},
#  {u'documentation_url': u'https://developer.github.com/v3/#rate-limiting',
# ...

# %%
files[0]['path']
# Out:
# u'98750/.0001.scavengerhunt'

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
